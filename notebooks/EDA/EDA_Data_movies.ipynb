# %% [markdown]
# # Exploratory data analysis
#
# Let's explore how the raw data might be structured or semistructured

# %%
filepath= r"MoviesOnStreamingPlatforms_updated.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(filepath, encoding="utf-8", index_col=["ID"])

# %%
df.describe()
# Out:
#          Unnamed: 0          Year          IMDb       Netflix          Hulu  \
# count  16744.000000  16744.000000  16173.000000  16744.000000  16744.000000
# mean    8371.500000   2003.014035      5.902751      0.212613      0.053930
# std     4833.720789     20.674321      1.347867      0.409169      0.225886
# min        0.000000   1902.000000      0.000000      0.000000      0.000000
# 25%     4185.750000   2000.000000      5.100000      0.000000      0.000000
# 50%     8371.500000   2012.000000      6.100000      0.000000      0.000000
# 75%    12557.250000   2016.000000      6.900000      0.000000      0.000000
# max    16743.000000   2020.000000      9.300000      1.000000      1.000000
#
#         Prime Video       Disney+     Type       Runtime
# count  16744.000000  16744.000000  16744.0  16152.000000
# mean       0.737817      0.033684      0.0     93.413447
# std        0.439835      0.180419      0.0     28.219222
# ...

# %%
df.head(50)
# Out:
#     Unnamed: 0                                 Title  Year  Age  IMDb  \
# ID
# 1            0                             Inception  2010  13+   8.8
# 2            1                            The Matrix  1999  18+   8.7
# 3            2                Avengers: Infinity War  2018  13+   8.5
# 4            3                    Back to the Future  1985   7+   8.5
# 5            4        The Good, the Bad and the Ugly  1966  18+   8.8
# 6            5     Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 7            6                           The Pianist  2002  18+   8.5
# 8            7                      Django Unchained  2012  18+   8.4
# 9            8               Raiders of the Lost Ark  1981   7+   8.4
# 10           9                  Inglourious Basterds  2009  18+   8.3
# 11          10                           Taxi Driver  1976  18+   8.3
# 12          11                              3 Idiots  2009  13+   8.4
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes',
#        'Netflix', 'Hulu', 'Prime Video', 'Disney+', 'Type', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')

# %% [markdown]
# # Resultados del análisis
#
# * La columna "0" no nos interesa
# * La columna "Age" podría ser reajustada para quitar el "+" y que se tome como un integer
# * Country, Genre y language son de interés pero son campos de "texto" que contienen varios datos. Esta estructura es bastante no-estructurada y podría ser dificil de normalizar (si es que se quiere normalizar....)
# * Rotten tomattos, que es una calificación basada en porcentaje debería ser un entero pero tiene un caracter "%" que no nos interesa
# * la clasificación en IMDB podría ser util y se puede usar como está.
